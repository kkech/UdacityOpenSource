# %%
#Upload Baisic Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Load the data
train = pd.read_csv("/content/drive/My Drive/WebTrafficData/train_1.csv")
keys = pd.read_csv("/content/drive/My Drive/WebTrafficData/key_1.csv")
#ss = pd.read_csv("../input/web-traffic-time-series-forecasting/sample_submission_1.csv")

# %%
train.head()
# Out:
#                                                 Page  ...  2016-12-31
# 0            2NE1_zh.wikipedia.org_all-access_spider  ...        20.0
# 1             2PM_zh.wikipedia.org_all-access_spider  ...        20.0
# 2              3C_zh.wikipedia.org_all-access_spider  ...        17.0
# 3         4minute_zh.wikipedia.org_all-access_spider  ...        11.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...  ...        10.0
#
# [5 rows x 551 columns]

# %%
#Check Missing Values
print("Check the number of records")
print("Number of records: ", train.shape[0], "\n")

print("Null analysis")
empty_sample = train[train.isnull().any(axis=1)]
print("Number of records containing null: ", empty_sample.shape[0], "\n")
# Out:
# Check the number of records
# Number of records:  145063
#
# Null analysis
# Number of records containing null:  27786

# %%
empty_sample.head(10)
# Out:
#                                                  Page  ...  2016-12-31
# 4   52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...  ...        10.0
# 6           91Days_zh.wikipedia.org_all-access_spider  ...         6.0
# 10           ASTRO_zh.wikipedia.org_all-access_spider  ...        51.0
# 13         AlphaGo_zh.wikipedia.org_all-access_spider  ...        11.0
# 19       B-PROJECT_zh.wikipedia.org_all-access_spider  ...         6.0
# 24      BLACK_PINK_zh.wikipedia.org_all-access_spider  ...        75.0
# 27  Beautiful_Mind_zh.wikipedia.org_all-access_spider  ...        14.0
# 37  Dear_My_Friends_zh.wikipedia.org_all-access_sp...  ...         9.0
# 38         Doctors_zh.wikipedia.org_all-access_spider  ...        68.0
# 48   Fantastic_Duo_zh.wikipedia.org_all-access_spider  ...        10.0
#
# [10 rows x 551 columns]

# %%
len(empty_sample)-10
# Out:
# 27776

# %%
len(empty_sample)
# Out:
# 27786

# %%
empty_sample.shape
# Out:
# (27786, 551)

# %%
train.Page[1]
# Out:
# '2PM_zh.wikipedia.org_all-access_spider'

# %%
res=re.search('[a-z][a-z].wikipedia.org',train.Page[1])

# %%
res[0][0:4]
# Out:
# 'zh.w'

# %%
def get_language(page):
    res = re.search('[a-z][a-z].wikipedia.org',page)
    if res:
        return res[0][0:2]
    return 'na'

train['lang'] = train.Page.map(get_language)

# %%
from collections import Counter

# %%
print(Counter(train.lang))
# Out:
# Counter({'en': 24108, 'ja': 20431, 'de': 18547, 'na': 17855, 'fr': 17802, 'zh': 17229, 'ru': 15022, 'es': 14069})

# %%
train[train.lang=='en'].iloc[:,0:-1]
# Out:
#                                                      Page  ...  2016-12-31
# 8357            !vote_en.wikipedia.org_desktop_all-agents  ...         0.0
# 8358    "Awaken,_My_Love!"_en.wikipedia.org_desktop_al...  ...      1770.0
# 8359    "European_Society_for_Clinical_Investigation"_...  ...         2.0
# 8360    "Weird_Al"_Yankovic_en.wikipedia.org_desktop_a...  ...      1098.0
# 8361       100_metres_en.wikipedia.org_desktop_all-agents  ...       272.0
# 8362    10_Cloverfield_Lane_en.wikipedia.org_desktop_a...  ...      3868.0
# 8363    10_Gigabit_Ethernet_en.wikipedia.org_desktop_a...  ...       298.0
# 8364    13_Hours:_The_Secret_Soldiers_of_Benghazi_en.w...  ...      2148.0
# 8365             1551_en.wikipedia.org_desktop_all-agents  ...        28.0
# 8366    1896_Summer_Olympics_en.wikipedia.org_desktop_...  ...       225.0
# 8367    1918_flu_pandemic_en.wikipedia.org_desktop_all...  ...      1440.0
# 8368    1923_San_Pedro_Maritime_Strike_en.wikipedia.or...  ...        49.0
# 8369    1936_Summer_Olympics_en.wikipedia.org_desktop_...  ...       488.0
# 8370    1976_Summer_Olympics_en.wikipedia.org_desktop_...  ...       271.0
# 8371    1980_Summer_Olympics_en.wikipedia.org_desktop_...  ...       314.0
# 8372    1984_Summer_Olympics_en.wikipedia.org_desktop_...  ...       345.0
# 8373    1989_(Taylor_Swift_album)_en.wikipedia.org_des...  ...       999.0
# 8374    1999_(Prince_album)_en.wikipedia.org_desktop_a...  ...       456.0
# 8375    2000_Summer_Olympics_en.wikipedia.org_desktop_...  ...       343.0
# 8376    2002_FIFA_World_Cup_en.wikipedia.org_desktop_a...  ...       616.0
# 8377    2003_invasion_of_Iraq_en.wikipedia.org_desktop...  ...       915.0
# 8378    2007_tuberculosis_scare_en.wikipedia.org_deskt...  ...        13.0
# 8379    2008_Summer_Olympics_en.wikipedia.org_desktop_...  ...       650.0
# 8380    2008_Summer_Olympics_medal_table_en.wikipedia....  ...       103.0
# 8381    2012_Benghazi_attack_en.wikipedia.org_desktop_...  ...      1926.0
# 8382    2012_Summer_Olympics_en.wikipedia.org_desktop_...  ...       804.0
# 8383    2012_Summer_Olympics_medal_table_en.wikipedia....  ...       207.0
# 8384    2014_FIFA_World_Cup_en.wikipedia.org_desktop_a...  ...      1464.0
# 8385    2015_NCAA_Men's_Division_I_Basketball_Tourname...  ...       211.0
# 8386    2015_San_Bernardino_attack_en.wikipedia.org_de...  ...       480.0
# ...                                                   ...  ...         ...
# 113921  Yuichi_Motai_en.wikipedia.org_all-access_all-a...  ...         NaN
# 113922  Yukio_Kagayama_en.wikipedia.org_all-access_all...  ...        14.0
# 113923  Yundamindera_Station_en.wikipedia.org_all-acce...  ...         6.0
# 113924   Yung_Wing_en.wikipedia.org_all-access_all-agents  ...        45.0
# 113925  Yungpaw_Ga_en.wikipedia.org_all-access_all-agents  ...         3.0
# 113926  Yvonne_Gancel_en.wikipedia.org_all-access_all-...  ...         7.0
# 113927  Yvonne_Neuwirth_en.wikipedia.org_all-access_al...  ...         7.0
# 113928  ZF_4HP18_transmission_en.wikipedia.org_all-acc...  ...         8.0
# 113929  Zach_Wahls_en.wikipedia.org_all-access_all-agents  ...        28.0
# 113930  Zakynthos_(person)_en.wikipedia.org_all-access...  ...        11.0
# 113931  Zamzama_Park_en.wikipedia.org_all-access_all-a...  ...         9.0
# 113932  Zanan-e_Emruz_en.wikipedia.org_all-access_all-...  ...         NaN
# 113933     Zaratha_en.wikipedia.org_all-access_all-agents  ...         6.0
# 113934  Zari_District_en.wikipedia.org_all-access_all-...  ...         7.0
# 113935  Zarka_(trope)_en.wikipedia.org_all-access_all-...  ...         6.0
# 113936  Zarqan,_Razavi_Khorasan_en.wikipedia.org_all-a...  ...         4.0
# 113937  Zavet_(disambiguation)_en.wikipedia.org_all-ac...  ...         NaN
# 113938  Zeebo_Inc._en.wikipedia.org_all-access_all-agents  ...        18.0
# 113939  Zero_Minus_Ten_en.wikipedia.org_all-access_all...  ...        29.0
# 113940  Zeroth_law_en.wikipedia.org_all-access_all-agents  ...         NaN
# 113941  Zgornji_Lehen_na_Pohorju_en.wikipedia.org_all-...  ...         4.0
# 113942    Zhao_Lin_en.wikipedia.org_all-access_all-agents  ...         2.0
# 113943  Zhejiang_Yueju_Troupe_en.wikipedia.org_all-acc...  ...         2.0
# 113944  Zheleznogorsk_Airport_en.wikipedia.org_all-acc...  ...         6.0
# 113945  Zhu_Qingyuan_en.wikipedia.org_all-access_all-a...  ...         4.0
# 113946  Zikanyrops_sparsa_en.wikipedia.org_all-access_...  ...         2.0
# 113947  Zillur_Rahman_John_en.wikipedia.org_all-access...  ...         7.0
# 113948   Zitadelle_en.wikipedia.org_all-access_all-agents  ...         3.0
# 113949  Zovashen_(Dzhannatlu),_Ararat_en.wikipedia.org...  ...         4.0
# 113950  Zurich.minds_en.wikipedia.org_all-access_all-a...  ...         7.0
#
# [24108 rows x 551 columns]

# %%
train = pd.read_csv("/content/drive/My Drive/WebTrafficData/train_1.csv")
keys = pd.read_csv("/content/drive/My Drive/WebTrafficData/key_1.csv")

# %%
print(train.columns)
# Out:
# Index(['Page', '2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04',
#        '2015-07-05', '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#        ...
#        '2016-12-22', '2016-12-23', '2016-12-24', '2016-12-25', '2016-12-26',
#        '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30', '2016-12-31'],
#       dtype='object', length=551)

# %%
page = train['Page']

# %%
train.head()
# Out:
#                                                 Page  ...  2016-12-31
# 0            2NE1_zh.wikipedia.org_all-access_spider  ...        20.0
# 1             2PM_zh.wikipedia.org_all-access_spider  ...        20.0
# 2              3C_zh.wikipedia.org_all-access_spider  ...        17.0
# 3         4minute_zh.wikipedia.org_all-access_spider  ...        11.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...  ...        10.0
#
# [5 rows x 551 columns]

# %%
X = train.drop('Page',axis = 1)
X.shape
# Out:
# (145063, 550)

# %%
Y = X['2016-12-31'].values
Y
# Out:
# array([20., 20., 17., ..., nan, nan, nan])

# %%
X = X.values

# %%
X
# Out:
# array([[18., 11.,  5., ..., 19., 18., 20.],
#        [11., 14., 15., ..., 45., 26., 20.],
#        [ 1.,  0.,  1., ...,  3.,  4., 17.],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
shape = X.shape
print("X",shape)
# Out:
# X (145063, 550)

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import torch.utils.data as data_utils
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import pickle as pkl

torch.manual_seed(1)  # reproducible
#torch.cuda.set_device(1)


batch_size = 1000
seq_len = 1
out_size = 1
pred_date_len = 60

# %%
print('scale data now...')
sc = MinMaxScaler()
X = np.reshape(sc.fit_transform(np.reshape(X,(-1,1))), shape)
Y = np.reshape(sc.fit_transform(np.reshape(Y,(-1,1))), -1)
print('done.')
# Out:
# scale data now...
# done.

# %%
#trian and test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.05)
print('Train size:',X_train.shape,'Test size:',X_test.shape)

trainDB=data_utils.TensorDataset(torch.from_numpy(X_train).float().unsqueeze(2),\
                                torch.from_numpy(Y_train).float().unsqueeze(1))
trainloader=data_utils.DataLoader(trainDB,batch_size=batch_size,shuffle=True)
testDB=data_utils.TensorDataset(torch.from_numpy(X_test).float().unsqueeze(2),\
                                torch.from_numpy(Y_test).float().unsqueeze(1))
testloader=data_utils.DataLoader(testDB,batch_size=batch_size,shuffle=True)
testdataiter=iter(testloader)
# Out:
# Train size: (137809, 550) Test size: (7254, 550)

# %%
class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()

        self.hidden_units = 128
        self.model = nn.Sequential()

        self.rnn = nn.RNN(
            input_size=seq_len,
            hidden_size=self.hidden_units,  # rnn hidden unit
            num_layers=2,  # number of rnn layer
            batch_first=True, # input & output will has batch size as 1st dimension. e.g. (batch, time_step, input_size)
            nonlinearity='relu',
            dropout=0.2
        )
        self.out = nn.Linear(self.hidden_units, 1)

    def forward(self, x, h_state):
        # x (batch, time_step, input_size)
        # h_state (n_layers, batch, hidden_size)
        # r_out (batch, time_step, hidden_size)
        r_out, h_state = self.rnn(x, h_state)

        outs = []  # save all predictions
        for time_step in range(r_out.size(1)):  # calculate output for each time step
            outs.append(self.out(r_out[:, time_step, :]))
        return torch.stack(outs, dim=1)[:,-1,:], h_state

# %%
def train():
    rnn = RNN().cuda()
    print(rnn)
    optimizer = torch.optim.Adam(rnn.parameters(), lr=1e-3)   # optimize all cnn parameters
    loss_func = nn.MSELoss()
    h_state = None      # for initial hidden state

    dataiter=iter(trainloader)
    for step in range(200):
        x_all, _ = dataiter.next()
        if x_all.size(0)<batch_size:
            dataiter = iter(trainloader)
            x_all, _ = dataiter.next()
        pos=np.random.randint(pred_date_len,x_all.size(1)-pred_date_len)
        # print('pos:',pos,x_all.size())
        x=Variable(x_all[:,:pos,:]).cuda()
        y=Variable(x_all[:,pos:pos+pred_date_len,:]).cuda()
        y=y.view(batch_size,pred_date_len)
        y=y.sum(dim=1)
        # print(x, y)

        prediction, h_state = rnn(x, h_state)   # rnn output
        # !! next step is important !!
        h_state = Variable(h_state.data)        # repack the hidden state, break the connection from last iteration

        loss = loss_func(prediction, y)         # cross entropy loss
        optimizer.zero_grad()                   # clear gradients for this training step
        loss.backward()                         # backpropagation, compute gradients
        print(step,loss.item())
        optimizer.step()                        # apply gradients

        # if step%10==0:
        #     evaluate(rnn,h_state)

    torch.save(rnn,'rnn.mdl')
    pkl.dump(h_state,open('h_state','wb'))
    print('saved rnn.mdl and h_state.')

# %%
if __name__=='__main__':
    #uncommnet the following code to predict
    #y_all = predict()
    #submit(y_all)
    #uncomment the following code to train
    train()
# Out:
# RNN(
#   (model): Sequential()
#   (rnn): RNN(1, 128, num_layers=2, batch_first=True, dropout=0.2)
#   (out): Linear(in_features=128, out_features=1, bias=True)
# )
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:443: UserWarning: Using a target size (torch.Size([1000])) that is different to the input size (torch.Size([1000, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# 0 nan
# 1 nan
# 2 nan
# 3 nan
# 4 nan
# 5 nan
# 6 nan
# 7 nan
# 8 nan
# 9 nan
# 10 nan
# 11 nan
# 12 nan
# 13 nan
# 14 nan
# 15 nan
# 16 nan
# 17 nan
# 18 nan
# 19 nan
# 20 nan
# 21 nan
# 22 nan
# 23 nan
# 24 nan
# 25 nan
# 26 nan
# 27 nan
# 28 nan
# 29 nan
# 30 nan
# 31 nan
# 32 nan
# 33 nan
# 34 nan
# 35 nan
# 36 nan
# 37 nan
# 38 nan
# 39 nan
# 40 nan
# 41 nan
# 42 nan
# 43 nan
# 44 nan
# 45 nan
# 46 nan
# 47 nan
# 48 nan
# 49 nan
# 50 nan
# 51 nan
# 52 nan
# 53 nan
# 54 nan
# 55 nan
# 56 nan
# 57 nan
# 58 nan
# 59 nan
# 60 nan
# 61 nan
# 62 nan
# 63 nan
# 64 nan
# 65 nan
# 66 nan
# 67 nan
# 68 nan
# 69 nan
# 70 nan
# 71 nan
# 72 nan
# 73 nan
# 74 nan
# 75 nan
# 76 nan
# 77 nan
# 78 nan
# 79 nan
# 80 nan
# 81 nan
# 82 nan
# 83 nan
# 84 nan
# 85 nan
# 86 nan
# 87 nan
# 88 nan
# 89 nan
# 90 nan
# 91 nan
# 92 nan
# 93 nan
# 94 nan
# 95 nan
# 96 nan
# 97 nan
# 98 nan
# 99 nan
# 100 nan
# 101 nan
# 102 nan
# 103 nan
# 104 nan
# 105 nan
# 106 nan
# 107 nan
# 108 nan
# 109 nan
# 110 nan
# 111 nan
# 112 nan
# 113 nan
# 114 nan
# 115 nan
# 116 nan
# 117 nan
# 118 nan
# 119 nan
# 120 nan
# 121 nan
# 122 nan
# 123 nan
# 124 nan
# 125 nan
# 126 nan
# 127 nan
# 128 nan
# 129 nan
# 130 nan
# 131 nan
# 132 nan
# 133 nan
# 134 nan
# 135 nan
# 136 nan
# 137 nan
# 138 nan
# 139 nan
# 140 nan
# 141 nan
# 142 nan
# 143 nan
# 144 nan
# 145 nan
# 146 nan
# 147 nan
# 148 nan
# 149 nan
# 150 nan
# 151 nan
# 152 nan
# 153 nan
# 154 nan
# 155 nan
# 156 nan
# 157 nan
# 158 nan
# 159 nan
# 160 nan
# 161 nan
# 162 nan
# 163 nan
# 164 nan
# 165 nan
# 166 nan
# 167 nan
# 168 nan
# 169 nan
# 170 nan
# 171 nan
# 172 nan
# 173 nan
# 174 nan
# 175 nan
# 176 nan
# 177 nan
# 178 nan
# 179 nan
# 180 nan
# 181 nan
# 182 nan
# 183 nan
# 184 nan
# 185 nan
# 186 nan
# 187 nan
# 188 nan
# 189 nan
# 190 nan
# 191 nan
# 192 nan
# 193 nan
# 194 nan
# 195 nan
# 196 nan
# 197 nan
# 198 nan
# 199 nan
# saved rnn.mdl and h_state.
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type RNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
